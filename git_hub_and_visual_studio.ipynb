# %% [markdown]
# #**github**
# **repostory is a place where we can create a file for our project**
#
# **new porject is place where we can track new issues,features, and other task that are realted to the cote within the repostory**
#
# **new project is part of github only**
#
# **new repostory is a part of github and git**
#
# ****

# %% [markdown]
# #**visual studio**
#
# **yesma file name ko side ma vako white color aairako xa vane that file is not saved if cross ko sign aaira ko xa vane that file is saved**

# %% [markdown]
# **git le collabration ma help garxa**
#
# **branch develop bata banxa**

# %% [markdown]
# new terminal
#
# arrow ani cmd ma convert garne

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
untrack file lai track gare paxi git ma staging area ma janxa

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
